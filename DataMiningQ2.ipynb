# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dataset = "/content/drive/MyDrive/DataMining/data_students"

# %%
## path to year wise data folders
TourismData2013 = f"{dataset}/TourismData_2013"
TourismData2014 = f"{dataset}/TourismData_2014"
TourismData2016 = f"{dataset}/TourismData_2016"
TourismData2017 = f"{dataset}/TourismData_2017"
TourismData2018 = f"{dataset}/TourismData_2018"
TourismData2019 = f"{dataset}/TourismData_2019"
TourismData2020 = f"{dataset}/TourismData_2020"
TourismData2021 = f"{dataset}/TourismData_2021"
TourismData2022 = f"{dataset}/TourismData_2022"

# %% [markdown]
# ## PEAK AND LEAN IN TERMS OF FEE

# %%
MonthWiseFeeFromTourism2013 = f"{TourismData2013}/MONTH-WISE FEE FROM TOURISM (CRORE) IN INDIA.xlsx"

# %%
df_MonthWiseFeeFromTourism = pd.read_excel(MonthWiseFeeFromTourism2013)

# %%
df_MonthWiseFeeFromTourism
# Out:
#         MONTH   2022  2021   2020   2019   2018   2017   2016   2015   2014  \
# 0     January   3843  4700  20200  18205  17755  15799  13671  12100  11664
# 1    February   4524  5477  18241  17959  17757  15353  13661  11642  11510
# 2       March   6385  6642   5830  16214  17222  14667  12985  11133  10479
# 3       April  10053  6891     71  17134  15620  14260  11495  10091   9179
# 4         May  10900  1730     94  13642  12752  12255  10260   9505   7936
# 5        June  13360  3157    208  16083  14398  12971  10677   9564   8366
# 6        July  16189  4105    307  18205  16976  14796  14285  11982  10284
# 7      August  12716  5251    479  17867  16492  13811  12553  11411  10385
# 8   September  13435  6549    686  16824  15150  13840  11642  10415   9057
# 9     October  13447  5094    831  17057  14701  14213  12100  10549  10041
# 10   November  15556  7022   1413  19840  16584  16528  14259  12649  11431
# ...

# %%
year2022 = df_MonthWiseFeeFromTourism.iloc[:, 1].tolist()
year2021 = df_MonthWiseFeeFromTourism.iloc[:, 2].tolist()
year2020 = df_MonthWiseFeeFromTourism.iloc[:, 3].tolist()
year2019 = df_MonthWiseFeeFromTourism.iloc[:, 4].tolist()
year2018 = df_MonthWiseFeeFromTourism.iloc[:, 5].tolist()
year2017 = df_MonthWiseFeeFromTourism.iloc[:, 6].tolist()
year2016 = df_MonthWiseFeeFromTourism.iloc[:, 7].tolist()
year2014 = df_MonthWiseFeeFromTourism.iloc[:, 9].tolist()

# %%
def findminmax(year):
      max_year = np.max(year)
      argmax_year = np.argmax(year)
      min_year = np.min(year)
      argmin_year = np.argmin(year)
      return max_year, argmax_year, min_year, argmin_year

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
def displayminmax(year,current_year):
  print(f"YEAR : {current_year}")
  max_year, argmax_year, min_year, argmin_year = findminmax(year)
  print(f"Peak Month : {months[argmax_year]}, Fee Collected : {max_year} Rs, Lean Month : {months[argmin_year]}, Fee Collected : {min_year} Rs, IN Crores")

# %%
displayminmax(year2022, 2022)
displayminmax(year2021, 2021)
displayminmax(year2020, 2020)
displayminmax(year2019, 2019)
displayminmax(year2018, 2018)
displayminmax(year2017, 2017)
displayminmax(year2016, 2016)
displayminmax(year2014, 2014)
# Out:
# YEAR : 2022
# Peak Month : December, Fee Collected : 19527 Rs, Lean Month : January, Fee Collected : 3843 Rs, IN Crores
# YEAR : 2021
# Peak Month : December, Fee Collected : 8452 Rs, Lean Month : May, Fee Collected : 1730 Rs, IN Crores
# YEAR : 2020
# Peak Month : January, Fee Collected : 20200 Rs, Lean Month : April, Fee Collected : 71 Rs, IN Crores
# YEAR : 2019
# Peak Month : December, Fee Collected : 22631 Rs, Lean Month : May, Fee Collected : 13642 Rs, IN Crores
# YEAR : 2018
# Peak Month : December, Fee Collected : 19474 Rs, Lean Month : May, Fee Collected : 12752 Rs, IN Crores
# YEAR : 2017
# Peak Month : December, Fee Collected : 19381 Rs, Lean Month : May, Fee Collected : 12255 Rs, IN Crores
# YEAR : 2016
# Peak Month : December, Fee Collected : 16558 Rs, Lean Month : May, Fee Collected : 10260 Rs, IN Crores
# YEAR : 2014
# Peak Month : December, Fee Collected : 12988 Rs, Lean Month : May, Fee Collected : 7936 Rs, IN Crores

# %% [markdown]
# ## BY CONTINENTS

# %%
NationalityWiseQuarterWiseFTAs2013 = f"{TourismData2013}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2014 = f"{TourismData2014}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2016 = f"{TourismData2016}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2017 = f"{TourismData2017}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2018 = f"{TourismData2018}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2019 = f"{TourismData2019}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2020 = f"{TourismData2020}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2021 = f"{TourismData2021}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"
NationalityWiseQuarterWiseFTAs2022 = f"{TourismData2022}/NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx"

# %%
df2013 = pd.read_excel(NationalityWiseQuarterWiseFTAs2013)
df2014 = pd.read_excel(NationalityWiseQuarterWiseFTAs2014)
df2016 = pd.read_excel(NationalityWiseQuarterWiseFTAs2016)
df2017 = pd.read_excel(NationalityWiseQuarterWiseFTAs2017)
df2018 = pd.read_excel(NationalityWiseQuarterWiseFTAs2018)
df2019 = pd.read_excel(NationalityWiseQuarterWiseFTAs2019)
df2020 = pd.read_excel(NationalityWiseQuarterWiseFTAs2020)
df2021 = pd.read_excel(NationalityWiseQuarterWiseFTAs2021)
df2022 = pd.read_excel(NationalityWiseQuarterWiseFTAs2022)

# %%
continents = ['North America', 'Central & South America', 'Western Europe', 'Eastern Europe', 'Africa', 'West Asia', 'South Asia', 'South East Asia', 'East Asia', 'Australasia']

# %%
continents = [continent.upper() for continent in continents]

# %%
def continent_splits_ranges(df):
  indices = []
  index = 0
  for country in df['Country of Nationality']:
    if country.upper() in continents:
      indices.append(index)
    index += 1
  indices.append(len(df['Country of Nationality']))

  ranges = []
  for i in range(len(indices)-1):
      ranges.append([indices[i]+1, indices[i+1]])
  return ranges

# %%
quarters = ['1st Quarter (Jan-Mar)', '2nd Quarter (Apr-June)', '3rd Quarter (July-Sep)', '4th Quarter (Oct-Dec)']

# %%
def calcluate_continent_purpose_split(df, year):
      continent_split = continent_splits_ranges(df)
      print(f"YEAR : {year}")
      for split, continent in zip(continent_split, continents):
        Q1 =df.iloc[split[0]:split[1]]['1st Quarter (Jan-Mar)'].sum()
        Q2 =df.iloc[split[0]:split[1]]['2nd Quarter (Apr-June)'].sum()
        Q3 =df.iloc[split[0]:split[1]]['3rd Quarter (July-Sep)'].sum()
        Q4 =df.iloc[split[0]:split[1]]['4th Quarter (Oct-Dec)'].sum()
        max_year, argmax_year, min_year, argmin_year = findminmax([Q1, Q2, Q3, Q4])
        print(f"{continent} : PEAK QUARTER : {quarters[argmax_year]}, LEAN QUARTER : {quarters[argmin_year]}")

# %%
calcluate_continent_purpose_split(df2013, 2013)
# Out:
# YEAR : 2013
# NORTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# WESTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2014, 2014)
# Out:
# YEAR : 2014
# NORTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# WESTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2016, 2016)
# Out:
# YEAR : 2016
# NORTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# WESTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2017, 2017)
# Out:
# YEAR : 2017
# NORTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# WESTERN EUROPE : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2018, 2018)
# Out:
# YEAR : 2018
# NORTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# WESTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2019, 2019)
# Out:
# YEAR : 2019
# NORTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# WESTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2020, 2020)
# Out:
# YEAR : 2020
# NORTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# WESTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AFRICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2021, 2021)
# Out:
# YEAR : 2021
# NORTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WESTERN EUROPE : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EASTERN EUROPE : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# WEST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)

# %%
calcluate_continent_purpose_split(df2022, 2022)
# Out:
# YEAR : 2022
# NORTH AMERICA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# CENTRAL & SOUTH AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# WESTERN EUROPE : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# EASTERN EUROPE : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AFRICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# WEST ASIA : PEAK QUARTER : 3rd Quarter (July-Sep), LEAN QUARTER : 1st Quarter (Jan-Mar)
# SOUTH ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# SOUTH EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# EAST ASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# AUSTRALASIA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)

# %% [markdown]
# ## BY COUNTRIES

# %%
continents = ['North America', 'Central & South America', 'Western Europe', 'Eastern Europe', 'Africa', 'West Asia', 'South Asia', 'South East Asia', 'East Asia', 'Australasia']

# %%
def remove_continent_rows(df):

    # Convert both DataFrame column and continents list to lowercase for comparison
    mask = ~df['Country of Nationality'].str.upper().isin([c.upper() for c in continents])

    # Apply the mask to filter the DataFrame
    df_filtered = df[mask]

    return df_filtered

# %%
def remove_other_rows_age(df):
    df = df[df['Country of Nationality'].str.upper() != 'OTHERS']
    return df

# %%
df2013 = remove_continent_rows(df2013)
df2014 = remove_continent_rows(df2014)
df2016 = remove_continent_rows(df2016)
df2017 = remove_continent_rows(df2017)
df2018 = remove_continent_rows(df2018)
df2019 = remove_continent_rows(df2019)
df2020 = remove_continent_rows(df2020)
df2021 = remove_continent_rows(df2021)
df2022 = remove_continent_rows(df2022)

# %%
df2013 = remove_other_rows_age(df2013)
df2014 = remove_other_rows_age(df2014)
df2016 = remove_other_rows_age(df2016)
df2017 = remove_other_rows_age(df2017)
df2018 = remove_other_rows_age(df2018)
df2019 = remove_other_rows_age(df2019)
df2020 = remove_other_rows_age(df2020)
df2021 = remove_other_rows_age(df2021)
df2022 = remove_other_rows_age(df2022)

# %%
def calcluate_country(df, year):
      # countries = df['Country of Nationality']
      print(f"YEAR : {year}")
      for index, row in df.iterrows():
    # Access data in each column for the current row
          country = row['Country of Nationality']
          q1 = row['1st Quarter (Jan-Mar)']
          q2 = row['2nd Quarter (Apr-June)']
          q3 = row['3rd Quarter (July-Sep)']
          q4 = row['4th Quarter (Oct-Dec)']
          max_year, argmax_year, min_year, argmin_year = findminmax([q1,q2,q3,q4])
          print(f"{country} : PEAK QUARTER : {quarters[argmax_year]}, LEAN QUARTER : {quarters[argmin_year]}")

# %%
calcluate_country(df2013, 2013)
# Out:
# YEAR : 2013
# Canada : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# United States of America : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# Argentina : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# Brazil : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# Mexico : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Austria : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Belgium : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Denmark : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Finland : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# France : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Germany : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2014, 2014)
# Out:
# YEAR : 2014
# Canada : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# United States of America : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# Argentina : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# Brazil : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Mexico : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Austria : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Belgium : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Denmark : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Finland : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# France : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Germany : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2016, 2016)
# Out:
# YEAR : 2016
# CANADA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# UNITED STATES OF AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# ARGENTINA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# BRAZIL : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# MEXICO : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# BELGIUM : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# DENMARK : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# FINLAND : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# FRANCE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# GERMANY : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2017, 2017)
# Out:
# YEAR : 2017
# CANADA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# UNITED STATES OF AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# ARGENTINA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# BRAZIL : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# MEXICO : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# AUSTRIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# BELGIUM : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# DENMARK : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# FINLAND : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# FRANCE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# GERMANY : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2018, 2018)
# Out:
# YEAR : 2018
# CANADA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# UNITED STATES OF AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# ARGENTINA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# BRAZIL : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# MEXICO : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# BELGIUM : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# DENMARK : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# FINLAND : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# FRANCE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# GERMANY : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2019, 2019)
# Out:
# YEAR : 2019
# CANADA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# UNITED STATES OF AMERICA : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 3rd Quarter (July-Sep)
# ARGENTINA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# BRAZIL : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# MEXICO : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# AUSTRIA : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# BELGIUM : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# DENMARK : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# FINLAND : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# FRANCE : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# GERMANY : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 3rd Quarter (July-Sep)
# ...

# %%
calcluate_country(df2020, 2020)
# Out:
# YEAR : 2020
# Canada : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# United States Of America : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Argentina : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Brazil : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Mexico : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Austria : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Belgium : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Denmark : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Finland : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# France : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# Germany : PEAK QUARTER : 1st Quarter (Jan-Mar), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2021, 2021)
# Out:
# YEAR : 2021
# Canada : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# United States Of America : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Argentina : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Brazil : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Mexico : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Austria : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Belgium : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Denmark : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Finland : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# France : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# Germany : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# ...

# %%
calcluate_country(df2022, 2022)
# Out:
# YEAR : 2022
# Canada : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 2nd Quarter (Apr-June)
# United States Of America : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Argentina : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Brazil : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Mexico : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Austria : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Belgium : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Denmark : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Finland : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# France : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# Germany : PEAK QUARTER : 4th Quarter (Oct-Dec), LEAN QUARTER : 1st Quarter (Jan-Mar)
# ...
